# %% [markdown]
# # DATA ANALYSIS WITH PANDAS

# %% [markdown]
# # ALL CARS DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv('D:\CarsData.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Laraib\AppData\Local\Temp\ipykernel_15040\2429350241.py:1: SyntaxWarning: invalid escape sequence '\C'
#   data = pd.read_csv('D:\CarsData.csv')

# %%
data.head(10)
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            I10  2017   7495       Manual    11630   Petrol  145  60.1
# 1           Polo  2017  10989       Manual     9200   Petrol  145  58.9
# 2       2 Series  2019  27990    Semi-Auto     1614   Diesel  145  49.6
# 3   Yeti Outdoor  2017  12495       Manual    30960   Diesel  150  62.8
# 4         Fiesta  2017   7999       Manual    19353   Petrol  125  54.3
# 5           C-HR  2019  26791    Automatic     2373   Hybrid  135  74.3
# 6           Kuga  2019  17990       Manual     7038   Petrol  145  34.4
# 7         Tiguan  2019  27490    Semi-Auto     3000   Petrol  145  30.4
# 8         Fiesta  2018   9891       Manual    31639   Petrol  145  65.7
# 9        A Class  2017  17498       Manual     9663   Diesel   30  62.8
#
#    engineSize Manufacturer
# 0         1.0       hyundi
# 1         1.0   volkswagen
# 2         2.0          BMW
# 3         2.0        skoda
# 4         1.2         ford
# ...

# %%
data.tail(10)
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 97702            A4  2016  15000    Automatic    37004   Diesel   20  70.6
# 97703          Polo  2017  11990    Semi-Auto    21271   Petrol   20  60.1
# 97704         Focus  2018  11995       Manual    15900   Petrol  145  57.7
# 97705          Kuga  2017  14795       Manual    25570   Diesel  150  60.1
# 97706          Golf  2015  17998       Manual    46294   Petrol  200  39.8
# 97707        Fiesta  2017  10447    Automatic     8337   Petrol  145  54.3
# 97708      3 Series  2014  14995       Manual    25372   Diesel   30  61.4
# 97709        Fiesta  2017   8950       Manual    19910   Petrol  125  54.3
# 97710         Astra  2017  10700    Automatic    24468   Petrol  125  50.4
# 97711   Grandland X  2019  15798       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# 97702         2.0         Audi
# 97703         1.2   volkswagen
# 97704         1.0         ford
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97712 entries, 0 to 97711
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         97712 non-null  object
#  1   year          97712 non-null  int64
#  2   price         97712 non-null  int64
#  3   transmission  97712 non-null  object
#  4   mileage       97712 non-null  int64
#  5   fuelType      97712 non-null  object
#  6   tax           97712 non-null  int64
#  7   mpg           97712 non-null  float64
#  8   engineSize    97712 non-null  float64
#  9   Manufacturer  97712 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 7.5+ MB

# %%
data.shape[0]
# Out:
# 97712

# %%
data.shape[1]
# Out:
# 10

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  97712.000000   97712.000000   97712.000000  97712.000000  97712.000000
# mean    2017.066502   16773.487555   23219.475499    120.142408     55.205623
# std        2.118661    9868.552222   21060.882301     63.357250     16.181659
# min     1970.000000     450.000000       1.000000      0.000000      0.300000
# 25%     2016.000000    9999.000000    7673.000000    125.000000     47.100000
# 50%     2017.000000   14470.000000   17682.500000    145.000000     54.300000
# 75%     2019.000000   20750.000000   32500.000000    145.000000     62.800000
# max     2024.000000  159999.000000  323000.000000    580.000000    470.800000
#
#          engineSize
# count  97712.000000
# mean       1.664913
# std        0.558574
# min        0.000000
# 25%        1.200000
# 50%        1.600000
# 75%        2.000000
# max        6.600000

# %%
# Data Cleaning

# %%
# get the number of missing data points per column
missing_values_count = data.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['year'].value_counts()
data_counts
# Out:
# year
# 2019    26165
# 2017    21616
# 2016    15724
# 2018    13570
# 2015     7586
# 2014     4053
# 2020     4040
# 2013     2590
# 2012      633
# 2011      432
# 2010      340
# 2009      277
# 2008      199
# 2007      163
# 2006       86
# 2005       69
# 2004       52
# 2003       34
# 2002       31
# 2001       20
# 2000        9
# 1998        8
# 1999        6
# 1997        4
# 1996        2
# 1970        2
# 2024        1
# Name: count, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['transmission'].value_counts()
data_counts
# Out:
# transmission
# Manual       55502
# Semi-Auto    22296
# Automatic    19905
# Other            9
# Name: count, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['mileage'].value_counts()

data_counts
# Out:
# mileage
# 10       647
# 5000     641
# 1000     615
# 6000     456
# 3000     371
#         ...
# 35897      1
# 26647      1
# 59044      1
# 32404      1
# 25372      1
# Name: count, Length: 42214, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['tax'].value_counts()

data_counts
# Out:
# tax
# 145    47377
# 150    10816
# 30      8423
# 20      8248
# 125     6562
# 0       6259
# 200     2424
# 160     2056
# 135     1217
# 205      696
# 165      679
# 235      662
# 260      530
# 140      369
# 300      341
# 240      202
# 325      185
# 265      174
# 305       99
# 555       78
# 570       57
# 330       51
# 10        25
# 565       22
# 190       19
# 195       16
# 120       14
# 115       12
# 155       12
# 580       10
# 230       10
# 270        9
# 315        8
# 220        7
# 280        6
# 290        6
# 540        6
# 185        5
# 250        4
# 255        3
# 245        3
# 130        2
# 210        2
# 110        2
# 295        1
# 535        1
# 520        1
# 515        1
# Name: count, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['mpg'].value_counts()

data_counts
# Out:
# mpg
# 60.1     6109
# 65.7     4669
# 54.3     3943
# 64.2     3563
# 51.4     3555
#          ...
# 38.1        1
# 122.9       1
# 48.4        1
# 20.0        1
# 17.8        1
# Name: count, Length: 208, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['engineSize'].value_counts()

data_counts
# Out:
# engineSize
# 2.0    26886
# 1.0    17083
# 1.5    11247
# 1.4    10893
# 1.6     8700
# 1.2     6718
# 3.0     5395
# 2.1     3970
# 1.8     1715
# 1.3     1307
# 1.7      907
# 1.1      558
# 2.2      466
# 2.5      454
# 4.0      355
# 0.0      268
# 2.9      170
# 2.3      145
# 4.4       79
# 2.4       72
# 5.0       52
# 5.5       44
# 2.8       41
# 1.9       27
# 3.2       27
# 4.2       26
# 4.7       24
# 5.2       23
# 3.5       20
# 6.2       13
# 2.7        8
# 0.6        7
# 6.0        2
# 6.6        2
# 3.7        2
# 4.1        2
# 4.5        1
# 4.3        1
# 5.4        1
# 6.3        1
# Name: count, dtype: int64

# %%
# Assuming covid_filled is the DataFrame containing the car dataset
data_counts = data['Manufacturer'].value_counts()

data_counts
# Out:
# Manufacturer
# ford          17811
# volkswagen    14893
# vauxhall      13258
# merc          12860
# BMW           10664
# Audi          10565
# toyota         6699
# skoda          6188
# hyundi         4774
# Name: count, dtype: int64

# %%
# Verify Column

print(data.columns)
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'Manufacturer'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the visualization environment
sns.set(style="whitegrid")
plt.figure(figsize=(20, 15))

data = pd.read_csv('D:\CarsData.csv')

# We have multiple columns, some of which are categorical, some are numerical, and some are boolean.
# We will visualize the first 10 rows of each column with a suitable plot for its data type.

# Define a function to choose the plot type based on the column data type
def plot_column_data(column_data, column_name, subplot_index):
    plt.subplot(4, 3, subplot_index)
    if column_data.dtype == 'O':  # Object type, likely categorical
        sns.countplot(y=column_data[:10], palette="Set2")
        plt.title(f'Distribution of {column_name} (Top 10)')
    elif column_data.dtype == bool:  # Boolean type
        sns.countplot(x=column_data[:10], palette="Set1")
        plt.title(f'Distribution of {column_name} (Top 10)')
    else:  # Numerical type
        sns.barplot(x=column_data[:10].index, y=column_data[:10], palette="rocket")
        plt.title(f'Values of {column_name} (Top 10)')

# Plotting the first 10 rows for each column
for i, column in enumerate(data.columns, 1):
    plot_column_data(data[column], column, i)

plt.tight_layout()
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# <>:8: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Laraib\AppData\Local\Temp\ipykernel_15040\1374458206.py:8: SyntaxWarning: invalid escape sequence '\C'
#   data = pd.read_csv('D:\CarsData.csv')
# C:\Users\Laraib\AppData\Local\Temp\ipykernel_15040\1374458206.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=column_data[:10], palette="Set2")
# C:\Users\Laraib\AppData\Local\Temp\ipykernel_15040\1374458206.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=column_data[:10].index, y=column_data[:10], palette="rocket")
# C:\Users\Laraib\AppData\Local\Temp\ipykernel_15040\1374458206.py:23: FutureWarning:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
data = pd.read_csv(r'D:\CarsData.csv')

# Limit data to the first 1000 rows
data = data.head(1000)

# Check the column names
print(data.columns)

# Adjust column names if necessary
# For example, if the column names are different, replace 'Year' and 'Price' with the correct column names

# Extract 'Year' and 'Price' columns
# Assuming 'Year' and 'Price' are the correct column names
years = data['year']
prices = data['price']

# Create a scatter chart
plt.scatter(years, prices)

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Price')
plt.title('Car Prices Over Time')

# Show the plot
plt.show()
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'Manufacturer'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
data = pd.read_csv(r'D:\CarsData.csv')

# Limit data to the first 100 rows
data = data.head(100)

# Group the data into 5-year intervals and sum the prices within each interval
grouped_data = data.groupby((data['year'] // 5) * 5)['price'].sum()

# Extract years and prices from grouped data
years = grouped_data.index
prices = grouped_data.values

# Create a pie chart
plt.pie(prices, labels=years, autopct='%1.1f%%')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Adding title
plt.title('Distribution of Car Prices Over 5-Year Intervals')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data for the bar chart
x = np.arange(5)
y = np.random.randint(1, 10, size=5)

# Create the bar chart
plt.bar(x, y, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Models')
plt.ylabel('engineSiz')
plt.title('Bar Chart')

# Define the directory path
directory = r'C:\path\to\save'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the plot as an image file
plt.savefig(os.path.join(directory, 'bar_chart.png'))

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for years and population
years = np.arange(1900, 2020, 10)
population = np.random.randint(10000, 1000000, size=len(years))

# Create the line chart
plt.plot(years, population, marker='o', color='skyblue', linestyle='-')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('tax')
plt.title('Historical Population Chart')

# Define the directory path
directory = r'C:\path\to\save'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the plot as an image file
plt.savefig(os.path.join(directory, 'historical_population_chart.png'))

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create the line graph
plt.plot(x, y)

# Add labels and title
plt.xlabel('Model')
plt.ylabel('mpg')
plt.title('Premium Vector Graph')

# Define the directory path
directory = r'C:\path\to\save'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the plot as an image file
plt.savefig(os.path.join(directory, 'premium_vector_graph.png'))

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
categories = ['Polo 1', 'Yeti Outd 2', 'Fiesta 3', 'Golf 4', 'Corsa 5']
values = np.random.randint(1, 100, size=len(categories))

# Create the bar graph
plt.bar(categories, values, color='skyblue')

# Add labels and title
plt.xlabel('model')
plt.ylabel('year')
plt.title('Vector Infographic Template Graph')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Define the directory path
directory = r'C:\path\to\save'

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the plot as an image file
plt.savefig(os.path.join(directory, 'vector_infographic_template_graph.png'))

# Show the plot
plt.show()

# %%
# Sample data
labels = ['Golf', 'Aygo', 'Fiesta', 'Karoq']
prices = [27750, 7130, 35000, 28000]  # Average prices for each model

# Plot the donut chart
plt.figure(figsize=(8, 6))
plt.pie(prices, labels=labels, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.4))

# Add a circle at the center to transform it into a donut chart
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# Add a title
plt.title('Distribution of Car Prices by Model')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['Golf', 'Aygo', 'Fiesta', 'Karoq']
prices = [27050, 67037, 35190, 288808]  # Average prices for each model

# Create x coordinates using indices of labels
x = range(len(labels))

# Plot the area chart
plt.figure(figsize=(8, 6))
plt.fill_between(x, prices, color="skyblue", alpha=0.4)

# Add labels and title
plt.xticks(x, labels)  # Set x-axis labels to car models
plt.xlabel('Car Model')
plt.ylabel('Price')
plt.title('Car Prices by Model')

# Show the plot
plt.show()

# %% [markdown]
# # conclusion

# %% [markdown]
# **The visualizations above represent the first 10 rows for each column in the dataset. They provide a preliminary look at the distribution and values across different attributes, including age, gender, time spent on different platforms, interests, location, demographics, profession, income, debt status, homeownership, and car ownership**.
